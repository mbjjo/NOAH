# %% [markdown]
# This documents shows how to see the results from the simulations and optimizations done by the NOAH RTC Tool.

# %%
import swmmtoolbox.swmmtoolbox as swmmtoolbox
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle

# %% [markdown]
# In the following the parameters needed to show the results are defined.

# %%
CSO_ids = ['1','47','20'] # The CSO'ids that are to be shown. These should be the same as the ones used for the objective function in the optimization. 
outfile = 'Rakvere_v2.out' # The output file with the results
timesteps = 5*60 # The length of the time steps in seconds This requires that all timesteps have same length.
variable = 'Flow_lost_flooding' # The variable to be plotted. For more options see: 
# swmmtoolbox.listvariables(outfile)

# %% [markdown]
# ## Reading .pickle file

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
pickle_in = open("First_step_simulations.pickle","rb")
df = pickle.load(pickle_in)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-5dd3fde21202> in <module>
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 pickle_in = open("First_step_simulations.pickle","rb")
#       5 df = pickle.load(pickle_in)
#       6 df
#
# FileNotFoundError: [Errno 2] No such file or directory: 'First_step_simulations.pickle'

# %%
size = 14 # fontsize

plt.figure(figsize = (10,6))
plt.plot(df['starting points'],df['objective values'])
plt.title('Results of first step of the optimization',fontsize = size+2)
plt.xlabel('starting points',fontsize = size)
plt.xticks(fontsize = size-2)
plt.ylabel('Objective value',fontsize = size)
plt.yticks(fontsize = size-2)
# plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-cef95bdae447> in <module>
#       2
#       3 plt.figure(figsize = (10,6))
# ----> 4 plt.plot(df['starting points'],df['objective values'])
#       5 plt.title('Results of first step of the optimization',fontsize = size+2)
#       6 plt.xlabel('starting points',fontsize = size)
#
# NameError: name 'df' is not defined

# %% [markdown]
# ## Showing time series of the simulation from the .out file

# %%
df = pd.concat(((swmmtoolbox.extract(outfile,['node',CSO_ids[i],variable]))for i in range(len(CSO_ids))),axis = 1)
df.head()
# Out:
#                      node_1_Flow_lost_flooding  node_47_Flow_lost_flooding  \
# 2019-11-07 00:15:00                        0.0                         0.0
# 2019-11-07 00:30:00                        0.0                         0.0
# 2019-11-07 00:45:00                        0.0                         0.0
# 2019-11-07 01:00:00                        0.0                         0.0
# 2019-11-07 01:15:00                        0.0                         0.0
#
#                      node_20_Flow_lost_flooding
# 2019-11-07 00:15:00                         0.0
# 2019-11-07 00:30:00                         0.0
# 2019-11-07 00:45:00                         0.0
# 2019-11-07 01:00:00                         0.0
# 2019-11-07 01:15:00                         0.0

# %%
size = 14 # fontsize

plt.figure(figsize = (14,6))
for i in range(len(CSO_ids)):
    plt.plot(df.index,df.iloc[:,i],label =CSO_ids[i])
plt.title('CSO volume during the simulation',fontsize = size+2)
plt.xlabel('Time of simulation',fontsize = size)
plt.xticks(fontsize = size-2)
plt.ylabel("CSO volume from CSO-id's [CMS]",fontsize = size)
plt.yticks(fontsize = size-2)
plt.legend()
plt.show()

# %%
df = pd.concat(((swmmtoolbox.extract(outfile,['node','',variable]))for i in range(len(CSO_ids))),axis = 1)
df.head()
# Out:
#                      node_1_Flow_lost_flooding  node_2_Flow_lost_flooding  \
# 2019-11-07 00:15:00                        0.0                        0.0
# 2019-11-07 00:30:00                        0.0                        0.0
# 2019-11-07 00:45:00                        0.0                        0.0
# 2019-11-07 01:00:00                        0.0                        0.0
# 2019-11-07 01:15:00                        0.0                        0.0
#
#                      node_3_Flow_lost_flooding  node_4_Flow_lost_flooding  \
# 2019-11-07 00:15:00                        0.0                        0.0
# 2019-11-07 00:30:00                        0.0                        0.0
# 2019-11-07 00:45:00                        0.0                        0.0
# 2019-11-07 01:00:00                        0.0                        0.0
# 2019-11-07 01:15:00                        0.0                        0.0
#
#                      node_5_Flow_lost_flooding  node_6_Flow_lost_flooding  \
# 2019-11-07 00:15:00                        0.0                        0.0
# 2019-11-07 00:30:00                        0.0                        0.0
# 2019-11-07 00:45:00                        0.0                        0.0
# 2019-11-07 01:00:00                        0.0                        0.0
# 2019-11-07 01:15:00                        0.0                        0.0
#
#                      node_7_Flow_lost_flooding  node_8_Flow_lost_flooding  \
# 2019-11-07 00:15:00                        0.0                        0.0
# 2019-11-07 00:30:00                        0.0                        0.0
# 2019-11-07 00:45:00                        0.0                        0.0
# 2019-11-07 01:00:00                        0.0                        0.0
# 2019-11-07 01:15:00                        0.0                        0.0
#
#                      node_9_Flow_lost_flooding  node_10_Flow_lost_flooding  \
# 2019-11-07 00:15:00                        0.0                         0.0
# 2019-11-07 00:30:00                        0.0                         0.0
# 2019-11-07 00:45:00                        0.0                         0.0
# 2019-11-07 01:00:00                        0.0                         0.0
# 2019-11-07 01:15:00                        0.0                         0.0
#
#                      ...  node_19226_Flow_lost_flooding  \
# 2019-11-07 00:15:00  ...                            0.0
# 2019-11-07 00:30:00  ...                            0.0
# 2019-11-07 00:45:00  ...                            0.0
# 2019-11-07 01:00:00  ...                            0.0
# 2019-11-07 01:15:00  ...                            0.0
#
#                      node_30338_Flow_lost_flooding  \
# 2019-11-07 00:15:00                            0.0
# 2019-11-07 00:30:00                            0.0
# 2019-11-07 00:45:00                            0.0
# 2019-11-07 01:00:00                            0.0
# 2019-11-07 01:15:00                            0.0
#
#                      node_5512_Flow_lost_flooding  \
# 2019-11-07 00:15:00                           0.0
# 2019-11-07 00:30:00                           0.0
# 2019-11-07 00:45:00                           0.0
# 2019-11-07 01:00:00                           0.0
# 2019-11-07 01:15:00                           0.0
#
#                      node_5511_Flow_lost_flooding  node_45_Flow_lost_flooding  \
# 2019-11-07 00:15:00                           0.0                         0.0
# 2019-11-07 00:30:00                           0.0                         0.0
# 2019-11-07 00:45:00                           0.0                         0.0
# 2019-11-07 01:00:00                           0.0                         0.0
# 2019-11-07 01:15:00                           0.0                         0.0
#
#                      node_46_Flow_lost_flooding  node_8027_Flow_lost_flooding  \
# 2019-11-07 00:15:00                         0.0                           0.0
# 2019-11-07 00:30:00                         0.0                           0.0
# 2019-11-07 00:45:00                         0.0                           0.0
# 2019-11-07 01:00:00                         0.0                           0.0
# 2019-11-07 01:15:00                         0.0                           0.0
#
#                      node_44_Flow_lost_flooding  node_43_Flow_lost_flooding  \
# 2019-11-07 00:15:00                         0.0                         0.0
# 2019-11-07 00:30:00                         0.0                         0.0
# 2019-11-07 00:45:00                         0.0                         0.0
# 2019-11-07 01:00:00                         0.0                         0.0
# 2019-11-07 01:15:00                         0.0                         0.0
#
#                      node_47_Flow_lost_flooding
# 2019-11-07 00:15:00                         0.0
# 2019-11-07 00:30:00                         0.0
# 2019-11-07 00:45:00                         0.0
# 2019-11-07 01:00:00                         0.0
# 2019-11-07 01:15:00                         0.0
#
# [5 rows x 1707 columns]

# %%
df.plot()

# %% [markdown]
# ## Computing CSO volume

# %%
CSO_volumne = (df*timesteps).sum()
total_CSO_volumne = CSO_volumne.sum()

print('Total CSO volume is {:.0f} m3\n'.format(total_CSO_volumne))
print("For the different CSO-id's this is:")
for  i in range(len(CSO_ids)):
    print('The  CSO volume of {} is {:.0f} m3'.format(CSO_ids[i],CSO_volumne[i]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-89e9a13c166d> in <module>
# ----> 1 CSO_volumne = (df*timesteps).sum()
#       2 total_CSO_volumne = CSO_volumne.sum()
#       3
#       4 print('Total CSO volume is {:.0f} m3\n'.format(total_CSO_volumne))
#       5 print("For the different CSO-id's this is:")
#
# NameError: name 'df' is not defined

# %% [markdown]
# From these results it can be seen how the first step of the optimization computes 10 different simulations and finds that the lowest one is at starting point 4.8. The flooding volume is here 69290 m3. <br>
# From here the optimization algorithms further reduces the CSO volume to 68514 m3.
